# %% [markdown]
# # 书籍推荐
#
#
#
#
#
# ## langchain
# <img src="./img/langchain.jpg" width="40%">
#
# ## llm
#
# <img src="./img/llm.jpg" width="40%">
#
#
# ## 强化学习
# <img src="./img/强化学习书籍.jpg" width="40%">
